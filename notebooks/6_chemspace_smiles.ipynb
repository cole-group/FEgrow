# %% [markdown]
# # FEgrow: An Open-Source Molecular Builder and Free Energy Preparation Workflow
#
# **Authors: Mateusz K Bieniek, Ben Cree, Rachael Pirie, Joshua T. Horton, Natalie J. Tatum, Daniel J. Cole**

# %% [markdown]
# ## Overview
#
# Building and scoring molecules can be further streamlined by employing our established protocol. Here we show how to quickly build a library and score the entire library.

# %%
import pandas as pd
import prody
from rdkit import Chem

import fegrow
from fegrow import ChemSpace

from fegrow.testing import core_5R83_path, smiles_5R83_core_path, rec_5R83_path

# %% [markdown]
# # Prepare the ligand template

# %%
scaffold = Chem.SDMolSupplier(core_5R83_path)[0]

# %% [markdown]
# As we are using already prepared Smiles that have the scaffold as a substructure, it is not needed to set any growing vector.

# %%
# create the chemical space
cs = ChemSpace()
# Out:
# Dask can be watched on http://192.168.178.20:37485/status
# /home/dresio/software/mambaforge/envs/fegrow/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8989 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37485 instead
#   warnings.warn(

# %%
# we're not growing the scaffold, we're superimposing bigger molecules on it
cs.add_scaffold(scaffold)
cs.add_protein(rec_5R83_path)
# Out:
# /home/dresio/code/fegrow/fegrow/package.py:793: UserWarning: The template does not have an attachement (Atoms with index 0, or in case of Smiles the * character. )
#   warnings.warn("The template does not have an attachement (Atoms with index 0, "

# %%
# load 50k smiles dataset from the study
smiles = pd.read_csv(smiles_5R83_core_path).Smiles.to_list()

# for testing, sort by size and pick small
smiles.sort(key=len)
# take 5 smallest smiles
smiles = smiles[:5]

# %%
# here we add Smiles which should already have been matched
# to the scaffold (rdkit Mol.HasSubstructureMatch)
cs.add_smiles(smiles, protonate=False)
cs
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Smiles</th>
#       <th>score</th>
#       <th>h</th>
#       <th>Training</th>
#       <th>Success</th>
#       <th>enamine_searched</th>
#       <th>enamine_id</th>
#       <th>2D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[H]c1nc([H])c(SF)c([H])c1[H]</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[H]c1nc([H])c(SI)c([H])c1[H]</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[H]c1nc([H])c(SCl)c([H])c1[H]</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[H]c1nc([H])c(SBr)c([H])c1[H]</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[H]c1nc([H])c(C#CF)c([H])c1[H]</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[H]c1nc([H])c(N=NF)c([H])c1[H]</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[H]c1nc([H])c(OC#N)c([H])c1[H]</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[H]c1nc([H])c(SC#N)c([H])c1[H]</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[H]c1nc([H])c(C#CI)c([H])c1[H]</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[H]c1nc([H])c(N=NI)c([H])c1[H]</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cs.evaluate()
# Out:
# Generated 2 conformers.
# Generated 2 conformers.
# Generated 2 conformers.
# Generated 2 conformers.
# Generated 1 conformers.
# Generated 6 conformers.
# Generated 2 conformers.
# Generated 4 conformers.
# Generated 1 conformers.
# Generated 2 conformers.
# Removed 0 conformers.
# Removed 0 conformers.
# Removed 0 conformers.
# Removed 0 conformers.
# Removed 0 conformers.
# Removed 0 conformers.
# Removed 0 conformers.
# Removed 0 conformers.
# Removed 0 conformers.
# Warning (not error because allow_undefined_stereo=True): RDMol has unspecified stereochemistry. Bonds with undefined stereochemistry are:
#  - Bond 6 (atoms 6-7 of element (N-N)
#
# Warning (not error because allow_undefined_stereo=True): RDMol has unspecified stereochemistry. Bonds with undefined stereochemistry are:
#  - Bond 6 (atoms 6-7 of element (N-N)
# Removed 0 conformers.
# /home/dresio/software/mambaforge/envs/fegrow/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Warning (not error because allow_undefined_stereo=True): RDMol has unspecified stereochemistry. Bonds with undefined stereochemistry are:
#  - Bond 6 (atoms 6-7 of element (N-N)
#
# Warning (not error because allow_undefined_stereo=True): RDMol has unspecified stereochemistry. Bonds with undefined stereochemistry are:
#  - Bond 6 (atoms 6-7 of element (N-N)
# Using force field
# using ani2x
# using ani2x
# Optimising conformer:   0%|                               | 0/1 [00:00<?, ?it/s]
# Using force field
# Optimising conformer: 100%|███████████████████████| 1/1 [00:01<00:00,  1.20s/it]
# using ani2x
# Using force field
# Optimising conformer: 100%|███████████████████████| 1/1 [00:02<00:00,  2.20s/it]
# Using force field
# using ani2x
# using ani2x
# Optimising conformer:   0%|                               | 0/2 [00:00<?, ?it/s]
# Optimising conformer:  50%|███████████▌           | 1/2 [00:00<00:00,  1.62it/s]
# Optimising conformer:  25%|█████▊                 | 1/4 [00:00<00:00,  5.57it/s]
# using ani2x
# Optimising conformer: 100%|███████████████████████| 2/2 [00:02<00:00,  1.00s/it]
#
# Optimising conformer:  50%|███████████▌           | 2/4 [00:01<00:01,  1.51it/s]
#
# Optimising conformer:  50%|███████████▌           | 1/2 [00:00<00:00,  4.53it/s]
# Optimising conformer:  75%|█████████████████▎     | 3/4 [00:02<00:00,  1.31it/s]
#
# Optimising conformer: 100%|███████████████████████| 2/2 [00:01<00:00,  1.08it/s]
#
# Optimising conformer: 100%|███████████████████████| 4/4 [00:03<00:00,  1.30it/s]
# /home/dresio/software/mambaforge/envs/fegrow/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# /home/dresio/software/mambaforge/envs/fegrow/lib/python3.10/site-packages/torchani/resources/
# /home/dresio/software/mambaforge/envs/fegrow/lib/python3.10/site-packages/torchani/resources/
# /home/dresio/software/mambaforge/envs/fegrow/lib/python3.10/site-packages/torchani/resources/
# /home/dresio/software/mambaforge/envs/fegrow/lib/python3.10/site-packages/torchani/resources/
# /home/dresio/software/mambaforge/envs/fegrow/lib/python3.10/site-packages/torchani/resources/
# /home/dresio/software/mambaforge/envs/fegrow/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# failed to equip `nnpops` with error: No module named 'NNPOps'failed to equip `nnpops` with error: No module named 'NNPOps'
#
# failed to equip `nnpops` with error: No module named 'NNPOps'
# failed to equip `nnpops` with error: No module named 'NNPOps'
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:   0%|                               | 0/2 [00:00<?, ?it/s]
# [W CUDAFunctions.cpp:109] Warning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (function operator())
# [W BinaryOps.cpp:594] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer:   0%|                               | 0/2 [00:00<?, ?it/s]
#
# Optimising conformer:  50%|███████████▌           | 1/2 [00:01<00:01,  1.80s/it]
# Optimising conformer: 100%|███████████████████████| 2/2 [00:03<00:00,  1.84s/it]
#
#
# Optimising conformer: 100%|███████████████████████| 2/2 [00:03<00:00,  1.94s/it]
# Optimising conformer:   0%|                               | 0/6 [00:00<?, ?it/s]2024-02-27 15:09:00,654 - distributed.worker - WARNING - Compute Failed
# Key:       _evaluate_atomic-eb10d302-42c7-418a-8fff-4232d2f4394a
# Function:  execute_task
# args:      ((<function apply at 0x79f9f84ebe20>, <function _evaluate_atomic at 0x79f916031900>, [<rdkit.Chem.rdchem.Mol object at 0x79f8bc27f100>, '[H]c1nc([H])c(SCl)c([H])c1[H]', '/home/dresio/code/fegrow/fegrow/testing/data/5R83_rec.pdb'], (<class 'dict'>, [['h', None], ['num_conf', 10], ['minimum_conf_rms', 0.5], ['scoring_function', None], ['gnina_gpu', False]])))
# kwargs:    {}
# Exception: 'RuntimeError("Can\'t redefine method: forward on class: __torch__.torchani.nn.ANIModel (of Python compilation unit at: 0x79f8400a9600)")'
#
#
#
# Optimising conformer: 100%|███████████████████████| 1/1 [00:04<00:00,  4.13s/it]
#
# Optimising conformer: 100%|███████████████████████| 2/2 [00:05<00:00,  2.68s/it]
#
#
#
# Optimising conformer:  17%|███▊                   | 1/6 [00:05<00:26,  5.34s/it]
#
#
# Optimising conformer: 100%|███████████████████████| 2/2 [00:07<00:00,  3.63s/it]
# Optimising conformer: 100%|███████████████████████| 6/6 [00:15<00:00,  2.54s/it]
#                            Smiles  \
# 0    [H]c1nc([H])c(SF)c([H])c1[H]
# 1    [H]c1nc([H])c(SI)c([H])c1[H]
# 2   [H]c1nc([H])c(SCl)c([H])c1[H]
# 3   [H]c1nc([H])c(SBr)c([H])c1[H]
# 4  [H]c1nc([H])c(C#CF)c([H])c1[H]
# 5  [H]c1nc([H])c(N=NF)c([H])c1[H]
# 6  [H]c1nc([H])c(OC#N)c([H])c1[H]
# 7  [H]c1nc([H])c(SC#N)c([H])c1[H]
# 8  [H]c1nc([H])c(C#CI)c([H])c1[H]
# 9  [H]c1nc([H])c(N=NI)c([H])c1[H]
#
#                                                 Mol  score     h  Training  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x79f8bebfe420>  3.752  <NA>      True
# 1  <rdkit.Chem.rdchem.Mol object at 0x79f8bebfe030>  3.933  <NA>      True
# 2  <rdkit.Chem.rdchem.Mol object at 0x79f8bebfe180>   <NA>  <NA>     False
# 3  <rdkit.Chem.rdchem.Mol object at 0x79f8bebfe340>   3.89  <NA>      True
# 4  <rdkit.Chem.rdchem.Mol object at 0x79f8bebfe490>   3.48  <NA>      True
# 5  <rdkit.Chem.rdchem.Mol object at 0x79f8bebfef10>  3.672  <NA>      True
# 6  <rdkit.Chem.rdchem.Mol object at 0x79f8bebfef80>  3.328  <NA>      True
# 7  <rdkit.Chem.rdchem.Mol object at 0x79f8bebfd700>  3.295  <NA>      True
# 8  <rdkit.Chem.rdchem.Mol object at 0x79f8bebfd770>  3.659  <NA>      True
# 9  <rdkit.Chem.rdchem.Mol object at 0x79f8bebfdd90>  3.906  <NA>      True
#
#   Success  enamine_searched enamine_id
# 0    True             False       <NA>
# 1    True             False       <NA>
# 2   False             False       <NA>
# 3    True             False       <NA>
# 4    True             False       <NA>
# 5    True             False       <NA>
# 6    True             False       <NA>
# 7    True             False       <NA>
# 8    True             False       <NA>
# 9    True             False       <NA>

# %%
cs
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Smiles</th>
#       <th>score</th>
#       <th>h</th>
#       <th>Training</th>
#       <th>Success</th>
#       <th>enamine_searched</th>
#       <th>enamine_id</th>
#       <th>2D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[H]c1nc([H])c(SF)c([H])c1[H]</td>
#       <td>3.752</td>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[H]c1nc([H])c(SI)c([H])c1[H]</td>
#       <td>3.933</td>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[H]c1nc([H])c(SCl)c([H])c1[H]</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[H]c1nc([H])c(SBr)c([H])c1[H]</td>
#       <td>3.89</td>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[H]c1nc([H])c(C#CF)c([H])c1[H]</td>
#       <td>3.48</td>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>[H]c1nc([H])c(N=NF)c([H])c1[H]</td>
#       <td>3.672</td>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>[H]c1nc([H])c(OC#N)c([H])c1[H]</td>
#       <td>3.328</td>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>[H]c1nc([H])c(SC#N)c([H])c1[H]</td>
#       <td>3.295</td>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>[H]c1nc([H])c(C#CI)c([H])c1[H]</td>
#       <td>3.659</td>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>[H]c1nc([H])c(N=NI)c([H])c1[H]</td>
#       <td>3.906</td>
#       <td>&lt;NA&gt;</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>&lt;NA&gt;</td>
#       <td style="text-align: center;"><div style="width: 200px; height: 200px" data-content="rdkit/molecule"><img src="data:image/png;base64,..." alt="Mol"/></div></td>
#     </tr>
#   </tbody>
# </table>
# </div>
